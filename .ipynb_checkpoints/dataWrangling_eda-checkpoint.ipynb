# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime as dt

# %%
train = pd.read_csv(r'C:\Users\Staff\Desktop\springboard\data\train.csv')
train.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday
# 0      1     1   2/5/2010      24924.50      False
# 1      1     1  2/12/2010      46039.49       True
# 2      1     1  2/19/2010      41595.55      False
# 3      1     1  2/26/2010      19403.54      False
# 4      1     1   3/5/2010      21827.90      False

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
features = pd.read_csv(r'C:\Users\Staff\Desktop\springboard\data\features.csv')
features.head(10)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
# 5      1  2010-03-12        57.79       2.667        NaN        NaN
# 6      1  2010-03-19        54.58       2.720        NaN        NaN
# 7      1  2010-03-26        51.45       2.732        NaN        NaN
# 8      1  2010-04-02        62.27       2.719        NaN        NaN
# 9      1  2010-04-09        65.86       2.770        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 711.9+ KB

# %%
df = pd.merge(features,train, on = ['Date','Store'], how = 'outer')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 429760 entries, 0 to 429759
# Data columns (total 15 columns):
# Store           429760 non-null int64
# Date            429760 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday_x     8190 non-null object
# Dept            421570 non-null float64
# Weekly_Sales    421570 non-null float64
# IsHoliday_y     421570 non-null object
# dtypes: float64(11), int64(1), object(3)
# memory usage: 52.5+ MB

# %% [markdown]
# Need to parse dates to be able to join the two dataframes.
# Ask about parsing during read_csv.
